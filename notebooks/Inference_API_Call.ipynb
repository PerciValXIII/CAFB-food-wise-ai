# %%
import requests

# Define the URL of the FastAPI endpoint
url = "http://54.173.76.227:8000/data/search"

# Replace with your actual Bearer token
bearer_token = "qwerty123@123"

# Define the headers
headers = {
    "Authorization": f"Bearer {bearer_token}",
    "Content-Type": "application/json"
}

# Define the JSON payload
payload = {
    "query": "Asian man",
    "collections": ["image"],
    "top_n_each": 5,
    "top_n_total": 10
}

# Make the POST request
response = requests.post(url, headers=headers, json=payload)

# Print the response
print("Status Code:", response.status_code)
print("Response Body:", response.json())
# Out:
# Status Code: 200
# Response Body: {'status': 'success', 'results': [{'id': '6ffa538e-272b-4747-b91d-fc230eafb2b9', 'version': 3, 'score': 0.4674792, 'payload': {'id': 4, 'source_type': 'image', 'file_id': 'blo_004.png', 'chunk_text': 'A smiling Asian man in a gray shirt poses in front of a green wall with a large green logo.'}, 'vector': None, 'shard_key': None, 'order_value': None}, {'id': '9714ee09-2171-4fc4-91ec-6419410e6dac', 'version': 462, 'score': 0.45225367, 'payload': {'id': 463, 'source_type': 'image', 'file_id': 'blo_462.png', 'chunk_text': 'A masked Asian woman and older white man, both wearing face masks, pose with a cardboard box in an outdoor setting with trees and other people visible in the background.'}, 'vector': None, 'shard_key': None, 'order_value': None}, {'id': '87c5d3f7-6f02-42e2-a06e-881c34ab08bd', 'version': 218, 'score': 0.44791993, 'payload': {'id': 219, 'source_type': 'image', 'file_id': 'blo_219.png', 'chunk_text': 'An elderly Asian man with a white beard, wearing a denim jacket, carefully places produce into an orange reusable grocery bag.'}, 'vector': None, 'shard_key': None, 'order_value': None}, {'id': 'c2633514-9dfc-4310-a5de-59d93f3c3086', 'version': 197, 'score': 0.42919436, 'payload': {'id': 198, 'source_type': 'image', 'file_id': 'blo_198.png', 'chunk_text': 'An elderly Asian man with a white beard, wearing a denim jacket, is carefully placing a red reusable shopping bag filled with fresh vegetables into the back of a car.'}, 'vector': None, 'shard_key': None, 'order_value': None}, {'id': '2e0aebd1-e1cc-4f2b-8af8-cf3557fdb7aa', 'version': 955, 'score': 0.40193236, 'payload': {'id': 956, 'source_type': 'image', 'file_id': 'col_009-006.png', 'chunk_text': 'A cartoon illustration shows a Black man with a beard, wearing an orange shirt, against a light beige background.'}, 'vector': None, 'shard_key': None, 'order_value': None}]}
